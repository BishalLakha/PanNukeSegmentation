# %% [markdown]
# ## Importing Required Packages

# %%
from fastai.vision.all import *
from pathlib import Path
import numpy as np
import os
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *
from fastai.callback.fp16 import *
from semtorch import get_segmentation_learner
# Out:
# /home/newrun2/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
path = Path("./data/train")

# %%
path.ls()
# Out:
# (#5) [Path('data/train/codes.txt'),Path('data/train/.DS_Store'),Path('data/train/masks'),Path('data/train/models'),Path('data/train/images')]

# %%
fnames = get_image_files(path/"images")
fnames[0]
# Out:
# Path('data/train/images/01308.png')

# %%
(path/"masks").ls()[0]
# Out:
# Path('data/train/masks/01308.png')

# %%
### Function to make correspondace between images and masks
def label_func(fn): return path/"masks"/f"{fn.stem}{fn.suffix}"

# %%
label_func(fnames[0])
# Out:
# Path('data/train/masks/01308.png')

# %%
def MaskBlockCustom(codes=None):
    "A `TransformBlock` for segmentation masks, potentially with `codes`"
    return TransformBlock(type_tfms=PILMask.create, item_tfms=AddMaskCodes(codes=codes), 
                          batch_tfms=IntToFloatTensor(div_mask=255))

# %% [markdown]
# ### Create Datablock

# %%
# !pip install albumentations

from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    Flip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

# %%
# Class for data augmentation
class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    def __init__(self, aug): 
        self.aug = aug
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])
    
transformPipeline=Compose([
                        Flip(p=0.5),
                        Transpose(p=0.5),
                        Rotate(p=0.40,limit=10)
                    ],p=1)

transformPipeline=SegmentationAlbumentationsTransform(transformPipeline)

# %%
def get_dls(bs, size):
    "Return dataloader"

    nuclie_seg = DataBlock(blocks=(ImageBlock, MaskBlockCustom()),
                       get_items = get_image_files,
                       get_y = label_func,
                       splitter=RandomSplitter(),
                       item_tfms=[Resize((size,size)),transformPipeline],
                       batch_tfms=Normalize.from_stats(*imagenet_stats),
                    )
    return nuclie_seg.dataloaders(path/"images", path=path, bs=bs)

# %%
dls = get_dls(8,156)

# %%
dls.show_batch(max_n=10)

# %%
class Dice(Metric):
    "Dice coefficient metric for binary target in segmentation"
    def __init__(self, axis=1): self.axis = axis
    def reset(self): self.inter,self.union = 0,0
    def accumulate(self, learn):
        pred,targ = flatten_check(learn.pred.argmax(dim=self.axis), learn.y)
        pred, targ = TensorBase(pred), TensorBase(targ)
        self.inter += (pred*targ).float().sum().item()
        self.union += (pred+targ).float().sum().item()

    @property
    def value(self): return 2. * self.inter/self.union if self.union > 0 else None

# %% [markdown]
# ##  Train Model

# %% [markdown]
# ## ResNet101

# %%
monitor_training="valid_loss"
comp_training=np.less

monitor_evaluating="dice"
comp_evaluating=np.greater

patience=2

# %%
# !pip install efficientnet-pytorch

# %%
dls = get_dls(6,156)

fname="ResNet101_best_before_resizing"

callbacksFitBeforeResizing = [
    ShowGraphCallback(),
#     EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_evaluating,comp=comp_evaluating,every_epoch=False,fname=fname)  
]

# %%
learn = unet_learner(dls, resnet101,n_out=2,metrics=Dice(),wd=1e-3,self_attention=True).to_fp16()

# %%
learn.summary()
# Out:
# DynamicUnet (Input shape: ['6 x 3 x 156 x 156'])
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      6 x 64 x 78 x 78
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      6 x 256 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 64 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      6 x 256 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      6 x 64 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      6 x 256 x 39 x 39
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      6 x 128 x 39 x 39
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      6 x 128 x 20 x 20
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      6 x 512 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      6 x 512 x 20 x 20
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      6 x 128 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      6 x 512 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      6 x 128 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      6 x 512 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      6 x 128 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      6 x 512 x 20 x 20
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 20 x 20
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 256 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      6 x 1024 x 10 x 10
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      6 x 512 x 10 x 10
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      6 x 512 x 5 x 5
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      6 x 2048 x 5 x 5
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      6 x 2048 x 5 x 5
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      6 x 512 x 5 x 5
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      6 x 2048 x 5 x 5
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      6 x 512 x 5 x 5
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      6 x 2048 x 5 x 5
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      6 x 4096 x 5 x 5
# Conv2d                                    75501568   True
# ReLU
# ____________________________________________________________________________
#                      6 x 2048 x 5 x 5
# Conv2d                                    75499520   True
# ReLU
# ____________________________________________________________________________
#                      6 x 4096 x 5 x 5
# Conv2d                                    8392704    True
# ReLU
# PixelShuffle
# BatchNorm2d                               2048       True
# Conv2d                                    37750784   True
# ReLU
# Conv2d                                    37750784   True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      6 x 4096 x 10 x 10
# Conv2d                                    8392704    True
# ReLU
# PixelShuffle
# BatchNorm2d                               1024       True
# Conv2d                                    21235200   True
# ReLU
# Conv2d                                    21235200   True
# ReLU
# ____________________________________________________________________________
#                      6 x 192 x 400
# Conv1d                                    294912     True
# Conv1d                                    294912     True
# Conv1d                                    2359296    True
# ReLU
# ____________________________________________________________________________
#                      6 x 3072 x 20 x 20
# Conv2d                                    4721664    True
# ReLU
# PixelShuffle
# BatchNorm2d                               512        True
# Conv2d                                    9438208    True
# ReLU
# Conv2d                                    9438208    True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      6 x 2048 x 39 x 39
# Conv2d                                    2099200    True
# ReLU
# PixelShuffle
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      6 x 288 x 78 x 78
# Conv2d                                    1493280    True
# ReLU
# Conv2d                                    746784     True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      6 x 1152 x 78 x 78
# Conv2d                                    332928     True
# ReLU
# PixelShuffle
# ResizeToOrig
# MergeLayer
# Conv2d                                    762420     True
# ReLU
# Conv2d                                    762420     True
# Sequential
# ReLU
# ____________________________________________________________________________
#                      6 x 2 x 156 x 156
# Conv2d                                    584        True
# ____________________________________________________________________________
#
# Total params: 361,011,248
# Total trainable params: 318,616,432
# Total non-trainable params: 42,394,816
#
# Optimizer used: <function Adam at 0x7fdea2cc5290>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - ModelToHalf
#   - TrainEvalCallback
#   - MixedPrecision
#   - Recorder
#   - ProgressCallback

# %%
learn.fine_tune(10,cbs=callbacksFitBeforeResizing)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.194494</td>
#       <td>0.175638</td>
#       <td>0.782726</td>
#       <td>02:16</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.7827263864145597.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.155714</td>
#       <td>0.263950</td>
#       <td>0.789908</td>
#       <td>02:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.152870</td>
#       <td>0.147569</td>
#       <td>0.822825</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.146898</td>
#       <td>0.144498</td>
#       <td>0.823522</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.138371</td>
#       <td>0.138215</td>
#       <td>0.832607</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.139416</td>
#       <td>0.144792</td>
#       <td>0.834815</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.124820</td>
#       <td>0.147347</td>
#       <td>0.835206</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.129333</td>
#       <td>0.130998</td>
#       <td>0.841893</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.122207</td>
#       <td>0.127408</td>
#       <td>0.846303</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.123968</td>
#       <td>0.126357</td>
#       <td>0.845993</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.117315</td>
#       <td>0.126309</td>
#       <td>0.847057</td>
#       <td>02:21</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.7899076022663343.
# Better model found at epoch 1 with dice value: 0.8228254633076348.
# Better model found at epoch 2 with dice value: 0.8235219536780619.
# Better model found at epoch 3 with dice value: 0.8326066048779289.
# Better model found at epoch 4 with dice value: 0.834815251706668.
# Better model found at epoch 5 with dice value: 0.8352059419843793.
# Better model found at epoch 6 with dice value: 0.8418927150441128.
# Better model found at epoch 7 with dice value: 0.8463032994560565.
# Better model found at epoch 9 with dice value: 0.8470569050137007.

# %% [markdown]
# ### ResNet50

# %%
learn.fine_tune(6,cbs=callbacksFitBeforeResizing)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.201420</td>
#       <td>0.166756</td>
#       <td>0.778025</td>
#       <td>01:42</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1667555868625641.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.155794</td>
#       <td>0.140602</td>
#       <td>0.821228</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.148822</td>
#       <td>0.138110</td>
#       <td>0.831527</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.140706</td>
#       <td>0.133492</td>
#       <td>0.825761</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.137855</td>
#       <td>0.128560</td>
#       <td>0.836301</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.131780</td>
#       <td>0.127582</td>
#       <td>0.845104</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.125724</td>
#       <td>0.124000</td>
#       <td>0.846333</td>
#       <td>01:45</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1406015008687973.
# Better model found at epoch 1 with valid_loss value: 0.13811038434505463.
# Better model found at epoch 2 with valid_loss value: 0.1334916204214096.
# Better model found at epoch 3 with valid_loss value: 0.1285601258277893.
# Better model found at epoch 4 with valid_loss value: 0.12758198380470276.
# Better model found at epoch 5 with valid_loss value: 0.12400010228157043.

# %% [markdown]
# #### Result

# %%
learn.show_results()

# %% [markdown]
# #### Progressive Resizing

# %%
fname="ResNet50_best_after_resizing"

callbacksFitAfterResizing = [
    ShowGraphCallback(),
#     EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]

# %%
learn.dls = get_dls(4, 256)

# %%
learn.fine_tune(10,cbs=callbacksFitAfterResizing)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.157504</td>
#       <td>0.146581</td>
#       <td>0.811151</td>
#       <td>04:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14658135175704956.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.135883</td>
#       <td>0.127068</td>
#       <td>0.840077</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136360</td>
#       <td>0.127471</td>
#       <td>0.837577</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.128327</td>
#       <td>0.130543</td>
#       <td>0.834408</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.131640</td>
#       <td>0.126002</td>
#       <td>0.837127</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.130078</td>
#       <td>0.124934</td>
#       <td>0.841194</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.122168</td>
#       <td>0.119484</td>
#       <td>0.848566</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.125189</td>
#       <td>0.118527</td>
#       <td>0.850405</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.118653</td>
#       <td>0.117173</td>
#       <td>0.851335</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.118496</td>
#       <td>0.117194</td>
#       <td>0.852197</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.115638</td>
#       <td>0.116512</td>
#       <td>0.853248</td>
#       <td>04:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.12706810235977173.
# Better model found at epoch 3 with valid_loss value: 0.12600240111351013.
# Better model found at epoch 4 with valid_loss value: 0.12493359297513962.
# Better model found at epoch 5 with valid_loss value: 0.11948437243700027.
# Better model found at epoch 6 with valid_loss value: 0.1185268983244896.
# Better model found at epoch 7 with valid_loss value: 0.11717250198125839.
# Better model found at epoch 9 with valid_loss value: 0.11651182174682617.

# %% [markdown]
# ### DenseNet

# %%
fname="Densenet121_best"

callbacksFitBeforeResizing = [
    ShowGraphCallback(),
#     EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]

# %%
dls = get_dls(4,156)

# %%
learn = unet_learner(dls,densenet ,n_out=2,metrics=Dice(),cbs=callbacksFitBeforeResizing).to_fp16()

# %%
learn.fine_tune(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.361872</td>
#       <td>0.270292</td>
#       <td>0.581432</td>
#       <td>04:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2702917456626892.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.231609</td>
#       <td>0.207259</td>
#       <td>0.719478</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.230725</td>
#       <td>0.205454</td>
#       <td>0.745399</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.212722</td>
#       <td>0.194953</td>
#       <td>0.740847</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.204118</td>
#       <td>0.186951</td>
#       <td>0.739003</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.197582</td>
#       <td>0.176740</td>
#       <td>0.770150</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.197341</td>
#       <td>0.179930</td>
#       <td>0.753621</td>
#       <td>04:40</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.20725856721401215.
# Better model found at epoch 1 with valid_loss value: 0.20545363426208496.
# Better model found at epoch 2 with valid_loss value: 0.19495268166065216.
# Better model found at epoch 3 with valid_loss value: 0.18695068359375.
# Better model found at epoch 4 with valid_loss value: 0.17673993110656738.

# %% [markdown]
# ### SemTorch

# %%
dls = get_dls(4,256)

# %%
def segmentron_splitter(model):
    return [params(model.backbone), params(model.head)]

# %%
fname="deeplabv3-segmentron-resnet50-manual-data-augmentation-before-resizing-WD-2-best"
callbacksFitBeforeResizing = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]

# %%
learn = get_segmentation_learner(dls=dls, number_classes=2, segmentation_type="Semantic Segmentation",
                                 architecture_name="deeplabv3+", backbone_name="resnet50", 
                                 metrics= Dice(),wd=1e-3,pretrained=True,normalize=True).to_fp16()

# %%
learn.freeze() # Freezing the backbone

# %%
learn.lr_find() # find learning rate
learn.recorder # plot learning rate graph
# Out:
# Recorder

# %%
learn.fit_one_cycle(10, slice(3e-3,3e-2),cbs=callbacksFitBeforeResizing)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.208373</td>
#       <td>0.224849</td>
#       <td>0.689284</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.194472</td>
#       <td>0.204655</td>
#       <td>0.720399</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.184637</td>
#       <td>0.209208</td>
#       <td>0.706880</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.169511</td>
#       <td>0.174148</td>
#       <td>0.779760</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.164856</td>
#       <td>0.176742</td>
#       <td>0.769259</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.149687</td>
#       <td>0.158897</td>
#       <td>0.807281</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.148987</td>
#       <td>0.154315</td>
#       <td>0.806523</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.141211</td>
#       <td>0.147826</td>
#       <td>0.818681</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.133680</td>
#       <td>0.144629</td>
#       <td>0.822372</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.134893</td>
#       <td>0.143769</td>
#       <td>0.823264</td>
#       <td>00:59</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2248491495847702.
# Better model found at epoch 1 with valid_loss value: 0.2046547681093216.
# Better model found at epoch 3 with valid_loss value: 0.1741476207971573.
# Better model found at epoch 5 with valid_loss value: 0.15889735519886017.
# Better model found at epoch 6 with valid_loss value: 0.15431508421897888.
# Better model found at epoch 7 with valid_loss value: 0.14782598614692688.
# Better model found at epoch 8 with valid_loss value: 0.14462918043136597.
# Better model found at epoch 9 with valid_loss value: 0.14376872777938843.

# %%
learn.load(fname)
learn.validate()
# Out:
# /home/newrun2/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py:55: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# (#2) [0.14376872777938843,0.823264128189589]

# %%
learn.lr_find() # find learning rate
learn.recorder # plot learning rate graph
# Out:
# Recorder

# %%
learn.unfreeze()
learn.lr_find() # find learning rate
learn.recorder # plot learning rate graph
# Out:
# Recorder

# %%
fname="deeplabv3-segmentron-resnet50-manual-data-augmentation-after-resizing-WD-3-best"
callbacksFitAfterUnfreeze = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]

# %%
learn.fit_one_cycle(10, slice(3e-6,3e-5),cbs=callbacksFitAfterUnfreeze)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.136377</td>
#       <td>0.144252</td>
#       <td>0.821557</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.140088</td>
#       <td>0.144916</td>
#       <td>0.821440</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.139169</td>
#       <td>0.143170</td>
#       <td>0.826147</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.140863</td>
#       <td>0.143625</td>
#       <td>0.823609</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.135142</td>
#       <td>0.143328</td>
#       <td>0.824898</td>
#       <td>00:59</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14425238966941833.
# Better model found at epoch 2 with valid_loss value: 0.1431700885295868.
# No improvement since epoch 2: early stopping

# %% [markdown]
# ### UNet2

# %%
from semtorch.utils.metrics import DiceUSquaredNet

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        # Change 255 for 1
        mask[mask==255]=1
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %%
size = 256
bs = 4
manual = DataBlock(blocks=(ImageBlock, MaskBlock()),
                   get_items = get_image_files,
                       get_y = label_func,
                       splitter=RandomSplitter(),
                   item_tfms=[Resize((size,size)), TargetMaskConvertTransform()]                  )
manual.summary(path/"images")
dls = manual.dataloaders(path/"images",bs=bs)
dls.show_batch(vmin=0,vmax=1,figsize=(12, 9))
# Out:
# Setting-up type transforms pipelines
# Collecting items from data/train/images
# Found 2656 items
# 2 datasets of sizes 2125,531
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: label_func -> PILBase.create
#
# Building one sample
#   Pipeline: PILBase.create
#     starting from
#       data/train/images/01228.png
#     applying PILBase.create gives
#       PILImage mode=RGB size=256x256
#   Pipeline: label_func -> PILBase.create
#     starting from
#       data/train/images/01228.png
#     applying label_func gives
#       data/train/masks/01228.png
#     applying PILBase.create gives
#       PILMask mode=L size=256x256
#
# Final sample: (PILImage mode=RGB size=256x256, PILMask mode=L size=256x256)
#
#
# Collecting items from data/train/images
# Found 2656 items
# 2 datasets of sizes 2125,531
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: label_func -> PILBase.create
# Setting up after_item: Pipeline: AddMaskCodes -> TargetMaskConvertTransform -> Resize -- {'size': (256, 256), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#
# Building one batch
# Applying item_tfms to the first sample:
#   Pipeline: AddMaskCodes -> TargetMaskConvertTransform -> Resize -- {'size': (256, 256), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} -> ToTensor
#     starting from
#       (PILImage mode=RGB size=256x256, PILMask mode=L size=256x256)
#     applying AddMaskCodes gives
#       (PILImage mode=RGB size=256x256, PILMask mode=L size=256x256)
#     applying TargetMaskConvertTransform gives
#       (PILImage mode=RGB size=256x256, PILMask mode=L size=256x256)
#     applying Resize -- {'size': (256, 256), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} gives
#       (PILImage mode=RGB size=256x256, PILMask mode=L size=256x256)
#     applying ToTensor gives
#       (TensorImage of size 3x256x256, TensorMask of size 256x256)
#
# Adding the next 3 samples
#
# No before_batch transform to apply
#
# Collating items in a batch
#
# Applying batch_tfms to the batch built
#   Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#     starting from
#       (TensorImage of size 4x3x256x256, TensorMask of size 4x256x256)
#     applying IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} gives
#       (TensorImage of size 4x3x256x256, TensorMask of size 4x256x256)

# %%
# dls = get_dls(8,156)

# %%
fname="u2net-data-augmentation-best"

callbacksBeforeResizing = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_evaluating,comp=comp_evaluating, patience=patience),
    SaveModelCallback(monitor=monitor_evaluating,comp=comp_evaluating,every_epoch=False,fname=fname)  
]

# %%
learn = get_segmentation_learner(dls=dls, number_classes=2, segmentation_type="Semantic Segmentation",
                                 architecture_name="u2^net", backbone_name="small", 
                                 metrics=[DiceUSquaredNet()],wd=1e-2,loss_func=CrossEntropyLossFlat()).to_native_fp16()
#learn.freeze() # Freezing the backbone

# %%
learn.summary()
# Out:
# U2NETP (Input shape: ['4 x 3 x 256 x 256'])
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      4 x 64 x 256 x 256
# Conv2d                                    1792       True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 256 x 256
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 128 x 128
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 256 x 256
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36928      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 128 x 128
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 128 x 128
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36928      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 64 x 64
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36928      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 32 x 32
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36928      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 16 x 16
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36928      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 8 x 8
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 16 x 16
# Conv2d                                    73792      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 16 x 16
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 32 x 32
# Conv2d                                    73792      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 32 x 32
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 64 x 64
# Conv2d                                    73792      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 64 x 64
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 128 x 128
# Conv2d                                    73792      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 128 x 128
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 128 x 128
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 256 x 256
# Conv2d                                    73792      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 256 x 256
# Conv2d                                    9232       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# MaxPool2d
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2320       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 16 x 16
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 32 x 32
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 64 x 64
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 128 x 128
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      4 x 64 x 256 x 256
# Conv2d                                    18496      True
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      4 x 1 x 256 x 256
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 128 x 128
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 64 x 64
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 32 x 32
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 16 x 16
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 8 x 8
# Conv2d                                    577        True
# ____________________________________________________________________________
#                      4 x 1 x 256 x 256
# Conv2d                                    7          True
# ____________________________________________________________________________
#
# Total params: 1,131,181
# Total trainable params: 1,131,181
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f0e122a8290>
# Loss function: <function muti_bce_loss_fusion at 0x7f0e10541830>
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback
#   - NativeMixedPrecision

# %%
learn.lr_find() # find learning rate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-bc7c58157c02> in <module>
# ----> 1 learn.lr_find() # find learning rate
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/schedule.py in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggestions)
#     222     n_epoch = num_it//len(self.dls.train) + 1
#     223     cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> 224     with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     225     if show_plot: self.recorder.plot_lr_find()
#     226     if suggestions:
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     204             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     205             self.n_epoch = n_epoch
# --> 206             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     207
#     208     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_fit(self)
#     195         for epoch in range(self.n_epoch):
#     196             self.epoch=epoch
# --> 197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
#     199     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_epoch(self)
#     189
#     190     def _do_epoch(self):
# --> 191         self._do_epoch_train()
#     192         self._do_epoch_validate()
#     193
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_train(self)
#     181     def _do_epoch_train(self):
#     182         self.dl = self.dls.train
# --> 183         self._with_events(self.all_batches, 'train', CancelTrainException)
#     184
#     185     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     159     def all_batches(self):
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#     163     def _do_one_batch(self):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in one_batch(self, i, b)
#     616         self.iter = i
#     617         self._split(b)
# --> 618         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     619
#     620
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in _do_one_batch(self)
#     602         if len(self.yb) == 0:
#     603             return
# --> 604         _, self.loss = self.loss_func(d0, d1, d2, d3, d4, d5, d6, *self.yb)
#     605         self('after_loss')
#     606         if not self.training: return
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in muti_bce_loss_fusion(d0, d1, d2, d3, d4, d5, d6, labels_v)
#     553 def muti_bce_loss_fusion(d0, d1, d2, d3, d4, d5, d6, labels_v):
#     554     aux=labels_v.unsqueeze(1)
# --> 555     loss0 = bce_loss(d0, aux)
#     556     loss1 = bce_loss(d1, aux)
#     557     loss2 = bce_loss(d2, aux)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     630                                                   self.weight,
#     631                                                   pos_weight=self.pos_weight,
# --> 632                                                   reduction=self.reduction)
#     633
#     634
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    2571                 binary_cross_entropy_with_logits, tens_ops, input, target, weight=weight,
#    2572                 size_average=size_average, reduce=reduce, reduction=reduction,
# -> 2573                 pos_weight=pos_weight)
#    2574     if size_average is not None or reduce is not None:
#    2575         reduction_enum = _Reduction.legacy_get_enum(size_average, reduce)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1066     raise TypeError("no implementation found for '{}' on types that implement "
#    1067                     '__torch_function__: {}'
# -> 1068                     .format(func_name, list(map(type, overloaded_args))))
#    1069
#    1070 def has_torch_function(relevant_args: Iterable[Any]) -> bool:
#
# TypeError: no implementation found for 'torch.nn.functional.binary_cross_entropy_with_logits' on types that implement __torch_function__: [<class 'fastai.torch_core.TensorImage'>, <class 'fastai.torch_core.TensorMask'>]

# %%
learn.fit_one_cycle(15, slice(1e-4,1e-3),cbs=callbacksBeforeResizing)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_epoch(self)
#     190     def _do_epoch(self):
# --> 191         self._do_epoch_train()
#     192         self._do_epoch_validate()
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_train(self)
#     182         self.dl = self.dls.train
# --> 183         self._with_events(self.all_batches, 'train', CancelTrainException)
#     184
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in one_batch(self, i, b)
#     617         self._split(b)
# --> 618         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     619
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in _do_one_batch(self)
#     603             return
# --> 604         _, self.loss = self.loss_func(d0, d1, d2, d3, d4, d5, d6, *self.yb)
#     605         self('after_loss')
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/semtorch/models/archs/u2net.py in muti_bce_loss_fusion(d0, d1, d2, d3, d4, d5, d6, labels_v)
#     554     aux=labels_v.unsqueeze(1)
# --> 555     loss0 = bce_loss(d0, aux)
#     556     loss1 = bce_loss(d1, aux)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     631                                                   pos_weight=self.pos_weight,
# --> 632                                                   reduction=self.reduction)
#     633
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    2572                 size_average=size_average, reduce=reduce, reduction=reduction,
# -> 2573                 pos_weight=pos_weight)
#    2574     if size_average is not None or reduce is not None:
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1067                     '__torch_function__: {}'
# -> 1068                     .format(func_name, list(map(type, overloaded_args))))
#    1069
#
# TypeError: no implementation found for 'torch.nn.functional.binary_cross_entropy_with_logits' on types that implement __torch_function__: [<class 'fastai.torch_core.TensorImage'>, <class 'fastai.torch_core.TensorMask'>]
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _do_fit(self)
#     196             self.epoch=epoch
# --> 197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     156         except ex: self(f'after_cancel_{event_type}')
# --> 157         finally:   self(f'after_{event_type}')        ;final()
#     158
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in __call__(self, event_name)
#     132
# --> 133     def __call__(self, event_name): L(event_name).map(self._call_one)
#     134
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/foundation.py in map(self, f, gen, *args, **kwargs)
#     153
# --> 154     def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#     155     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     640     if gen: return res
# --> 641     return list(res)
#     642
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     630         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 631         return self.func(*fargs, **kwargs)
#     632
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _call_one(self, event_name)
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in <listcomp>(.0)
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      43         res = None
# ---> 44         if self.run and _run: res = getattr(self, event_name, noop)()
#      45         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/progress.py in after_epoch(self)
#      87         iters = range_of(rec.losses)
# ---> 88         val_losses = [v[1] for v in rec.values]
#      89         x_bounds = (0, (self.n_epoch - len(self.nb_batches)) * self.nb_batches[0] + len(rec.losses))
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/progress.py in <listcomp>(.0)
#      87         iters = range_of(rec.losses)
# ---> 88         val_losses = [v[1] for v in rec.values]
#      89         x_bounds = (0, (self.n_epoch - len(self.nb_batches)) * self.nb_batches[0] + len(rec.losses))
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/foundation.py in __getitem__(self, idx)
#     110     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
# --> 111     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     112     def copy(self): return self._new(self.items.copy())
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/foundation.py in _get(self, i)
#     114     def _get(self, i):
# --> 115         if is_indexer(i) or isinstance(i,slice): return getattr(self.items,'iloc',self.items)[i]
#     116         i = mask2idxs(i)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-4cb234e8a562> in <module>
# ----> 1 learn.fit_one_cycle(15, slice(1e-4,1e-3),cbs=callbacksBeforeResizing)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#     110     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     111               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 112     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     113
#     114 # Cell
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     204             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     205             self.n_epoch = n_epoch
# --> 206             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     207
#     208     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
# --> 157         finally:   self(f'after_{event_type}')        ;final()
#     158
#     159     def all_batches(self):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in __call__(self, event_name)
#     131     def ordered_cbs(self, event): return [cb for cb in sort_by_run(self.cbs) if hasattr(cb, event)]
#     132
# --> 133     def __call__(self, event_name): L(event_name).map(self._call_one)
#     134
#     135     def _call_one(self, event_name):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/foundation.py in map(self, f, gen, *args, **kwargs)
#     152     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     153
# --> 154     def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#     155     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     156     def filter(self, f=noop, negate=False, gen=False, **kwargs):
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     639     res = map(g, iterable)
#     640     if gen: return res
# --> 641     return list(res)
#     642
#     643 # Cell
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     629             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     630         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 631         return self.func(*fargs, **kwargs)
#     632
#     633 # Cell
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in _call_one(self, event_name)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in <listcomp>(.0)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      42                (self.run_valid and not getattr(self, 'training', False)))
#      43         res = None
# ---> 44         if self.run and _run: res = getattr(self, event_name, noop)()
#      45         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#      46         return res
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/callback/tracker.py in after_fit(self, **kwargs)
#      85     def after_fit(self, **kwargs):
#      86         "Load the best model."
# ---> 87         if not self.every_epoch: self.learn.load(f'{self.fname}', with_opt=self.with_opt)
#      88
#      89 # Cell
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in load(self, file, with_opt, device, **kwargs)
#     292         if self.opt is None: self.create_opt()
#     293         file = join_path_file(file, self.path/self.model_dir, ext='.pth')
# --> 294         load_model(file, self.model, self.opt, with_opt=with_opt, device=device, **kwargs)
#     295         return self
#     296
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/fastai/learner.py in load_model(file, model, opt, with_opt, device, strict)
#      45     if isinstance(device, int): device = torch.device('cuda', device)
#      46     elif device is None: device = 'cpu'
# ---> 47     state = torch.load(file, map_location=device)
#      48     hasopt = set(state)=={'model', 'opt'}
#      49     model_state = state['model'] if hasopt else state
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~/Projects/Marwen/venv/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train/models/u2net-data-augmentation-best.pth'
